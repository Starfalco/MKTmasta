# %%
import mysql.connector as connection
import pandas as pd
from sqlalchemy import create_engine, types

# %%
mydb = connection.connect(host="localhost", database = 'shiva',user="root",use_pure=True)
print(mydb.get_server_info())
query = "Select * from clients2;"
result_dataFrame = pd.read_sql(query,mydb)
print(result_dataFrame)
mydb.close() #close the connection
# Out:
# 5.5.5-10.4.32-MariaDB
#   COL 1    COL 2       COL 3   COL 4   COL 5
# 0    ID  Surname  First Name  Number  Adress
# 1     1        3         fff      10      tr
# 2     2        3         fff     101     rtr
# C:\Users\yoman\AppData\Local\Temp\ipykernel_36636\168108722.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_dataFrame = pd.read_sql(query,mydb)

# %%
df = pd.read_csv(r"C:\Users\yoman\OneDrive\Documents\GitHub\MKTmasta\extracts\price\price.csv", sep=";", encoding="utf-8")
filtered_df = df.dropna()
print(filtered_df)
filtered_df.to_csv(r"C:\Users\yoman\OneDrive\Documents\GitHub\MKTmasta\extracts\price\price_filtered.csv", sep=';', encoding='utf-8')
# Out:
#                             Date Ticker        Open        High         Low  \
# 1      2024-06-03 00:00:00+00:00      A  130.000000  132.580002  130.000000
# 3      2024-06-03 00:00:00+00:00      A  130.000000  132.580002  130.000000
# 5      2024-06-03 00:00:00+00:00    AAL   11.600000   11.950000   11.500000
# 6      2024-06-03 00:00:00+00:00   AAPL  192.899994  194.990005  192.520004
# 7      2024-06-03 00:00:00+00:00   ABBV  160.000000  163.190002  158.830002
# ...                          ...    ...         ...         ...         ...
# 15929  2024-06-28 00:00:00+00:00    XYL  136.639999  137.990005  134.300003
# 15930  2024-06-28 00:00:00+00:00    YUM  132.509995  132.990005  131.720001
# 15931  2024-06-28 00:00:00+00:00    ZBH  108.550003  109.580002  107.379997
# 15932  2024-06-28 00:00:00+00:00   ZBRA  309.000000  314.040009  306.160004
# 15933  2024-06-28 00:00:00+00:00    ZTS  176.460007  177.070007  173.029999
#
#             Close   Adj Close      Volume
# ...

# %%
print(df.columns)
# Out:
# Index(['Date;Ticker;Open;High;Low;Close;Adj Close;Volume'], dtype='object')

# %%
engine = create_engine("mysql+mysqlconnector://root@localhost/sp500 data") # enter your password and database names here
df = pd.read_csv(r"extracts\price\price_filtered.csv",sep=';',encoding='utf8') # Replace Excel_file_name with your excel sheet name
df.to_sql('price_historic',con=engine,index=False,if_exists='append') # Replace Table_name with your sql table name
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[52], line 3
#       1 engine = create_engine("mysql+mysqlconnector://root@localhost/sp500 data") # enter your password and database names here
#       2 df = pd.read_csv(r"extracts\price\price_filtered.csv",sep=';',encoding='utf8') # Replace Excel_file_name with your excel sheet name
# ----> 3 df.to_sql('price_historic',con=engine,index=False,if_exists='append') # Replace Table_name with your sql table name
#
# File c:\Users\yoman\OneDrive\Documents\GitHub\MKTmasta\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
# ...
